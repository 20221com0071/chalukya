# %% [markdown]
# <a href="https://colab.research.google.com/github/20221com0071/chalukya/blob/main/Untitled16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('/content/Untitled Folder/train (1).csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
age_mean_value=df['Age'].mean()
df['Age']=df['Age'].fillna(age_mean_value)

# %%
sorted_passengers = df.sort_values('Name',ascending=True,kind='heapsort')
sorted_passengers.head(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 845          846         0       3
# 746          747         0       3
# 279          280         1       3
# 308          309         0       2
# 874          875         1       2
# 365          366         0       3
# 401          402         0       3
# 40            41         0       3
# 855          856         1       3
# 207          208         1       3
#
#                                                Name     Sex   Age  SibSp  \
# 845                             Abbing, Mr. Anthony    male  42.0      0
# 746                     Abbott, Mr. Rossmore Edward    male  16.0      1
# 279                Abbott, Mrs. Stanton (Rosa Hunt)  female  35.0      1
# 308                             Abelson, Mr. Samuel    male  30.0      1
# 874           Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.0      1
# 365                  Adahl, Mr. Mauritz Nils Martin    male  30.0      0
# ...

# %%
merged_df=pd.merge(df.head(2),df.tail(2),how='outer',indicator=True)

# %%
merged_df
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2          890         1       1
# 3          891         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Behr, Mr. Karl Howell    male  26.0      0
# 3                                Dooley, Mr. Patrick    male  32.0      0
#
#    Parch     Ticket     Fare Embarked      _merge
# 0      0  A/5 21171   7.2500        S   left_only
# 1      0   PC 17599  71.2833        C   left_only
# 2      0     111369  30.0000        C  right_only
# 3      0     370376   7.7500        Q  right_only

# %%
group_df=df.groupby('Name')
group_df
